# %% [markdown]
# ## crea la tabla de estaciones

# %%
##Para crear tabla de estaciones disponibles.
import pandas as pd
import re
#el string se consiguio del js de sinaica de 'https://sinaica.inecc.gob.mx/scica/'
string="""<optgroup label='Red: Abasolo' ><option data-tokens="Guanajuato GTO ABA Abasolo Presidencia Municipal ABA" value='356'>Presidencia Municipal</option></optgroup><optgroup label='Red: Acámbaro' ></optgroup><optgroup label='Red: Aguascalientes' ><option data-tokens="Aguascalientes AGS AGS Aguascalientes CBTIS  CBT" value='31'>CBTIS </option><option data-tokens="Aguascalientes AGS AGS Aguascalientes Centro CEN" value='33'>Centro</option><option data-tokens="Aguascalientes AGS AGS Aguascalientes Instituto Educativo IED" value='303'>Instituto Educativo</option><option data-tokens="Aguascalientes AGS AGS Aguascalientes Secretaría de Medio Ambiente SMA" value='32'>Secretaría de Medio Ambiente</option></optgroup><optgroup label='Red: Ajacuba' ></optgroup><optgroup label='Red: Apizaco' ><option data-tokens="Tlaxcala TLAX APZ Apizaco Centro de Salud CSA" value='438'>Centro de Salud</option></optgroup><optgroup label='Red: Atitalaquia' ><option data-tokens="Hidalgo HGO ATI Atitalaquia Centro de Salud ATI" value='82'>Centro de Salud</option></optgroup><optgroup label='Red: Atotonilco' ><option data-tokens="Hidalgo HGO ATO Atotonilco Primaria Revolución ATO" value='83'>Primaria Revolución</option></optgroup><optgroup label='Red: Balancán' ></optgroup><optgroup label='Red: Campeche' ><option data-tokens="Campeche CAMP CAMP Campeche Campus II Esc. Prep. Dr. Nazario Víctor Montejo Godoy - Universidad Autónoma de Campeche. PRE" value='435'>Campus II Esc. Prep. Dr. Nazario Víctor Montejo Godoy - Universidad Autónoma de Campeche.</option></optgroup><optgroup label='Red: Celaya' ><option data-tokens="Guanajuato GTO CEL Celaya Policía POL" value='68'>Policía</option><option data-tokens="Guanajuato GTO CEL Celaya San Juanico SJ" value='70'>San Juanico</option><option data-tokens="Guanajuato GTO CEL Celaya Tecnológico TEC" value='69'>Tecnológico</option></optgroup><optgroup label='Red: Centla' ></optgroup><optgroup label='Red: Centro' ><option data-tokens="Tabasco TAB CEN Centro Instituto Tecnológico de Villahermosa ITVH" value='192'>Instituto Tecnológico de Villahermosa</option></optgroup><optgroup label='Red: CHIH1' ><option data-tokens="Chihuahua -Estatal CHIH1 CHIH1 CHIH1 Centro CEN" value='54'>Centro</option><option data-tokens="Chihuahua -Estatal CHIH1 CHIH1 CHIH1 SUR SUR" value='53'>SUR</option></optgroup><optgroup label='Red: CHIH2' ><option data-tokens="Chihuahua - Municipal CHIH2 CHIH2 CHIH2 CIMAV CIMAV" value='55'>CIMAV</option></optgroup><optgroup label='Red: Ciudad Juárez 2' ><option data-tokens="Chihuahua - UACJ CHIH5 CJU2 Ciudad Juárez 2 Instituto de Ingeniería y Tecnología IIT" value='428'>Instituto de Ingeniería y Tecnología</option></optgroup><optgroup label='Red: Colima' ><option data-tokens="Colima COL COL Colima Tecnologico TEC" value='57'>Tecnologico</option></optgroup><optgroup label='Red: Corregidora' ><option data-tokens="Querétaro QRO COR Corregidora Corregidora COR" value='166'>Corregidora</option></optgroup><optgroup label='Red: Cortazar' ></optgroup><optgroup label='Red: Cuernavaca' ><option data-tokens="Morelos MOR CUE Cuernavaca Cuernavaca 01 PGO" value='134'>Cuernavaca 01</option></optgroup><optgroup label='Red: Culiacán' ><option data-tokens="Sinaloa SIN CUL Culiacán Culiacan ECLN1" value='411'>Culiacan</option></optgroup><optgroup label='Red: Dolores Hidalgo' ></optgroup><optgroup label='Red: Durango' ><option data-tokens="Durango DGO DGO Durango IPN IPN" value='59'>IPN</option><option data-tokens="Durango DGO DGO Durango ITD ITD" value='58'>ITD</option><option data-tokens="Durango DGO DGO Durango SRNyMA SRN" value='60'>SRNyMA</option></optgroup><optgroup label='Red: El Marques' ><option data-tokens="Querétaro QRO MAR El Marques El Marqués EMA" value='167'>El Marqués</option></optgroup><optgroup label='Red: Gómez Palacio' ><option data-tokens="Durango DGO GPD Gómez Palacio Campestre CAM" value='65'>Campestre</option><option data-tokens="Durango DGO GPD Gómez Palacio Parque La Esperanza ESP" value='430'>Parque La Esperanza</option></optgroup><optgroup label='Red: Guadalajara' ><option data-tokens="Jalisco JAL GDL Guadalajara Atemajac ATM" value='101'>Atemajac</option><option data-tokens="Jalisco JAL GDL Guadalajara Centro  CEN" value='102'>Centro </option><option data-tokens="Jalisco JAL GDL Guadalajara Las Águilas AGU" value='103'>Las Águilas</option><option data-tokens="Jalisco JAL GDL Guadalajara Las Pintas PIN" value='104'>Las Pintas</option><option data-tokens="Jalisco JAL GDL Guadalajara Loma Dorada LDO" value='105'>Loma Dorada</option><option data-tokens="Jalisco JAL GDL Guadalajara Miravalle MIR" value='106'>Miravalle</option><option data-tokens="Jalisco JAL GDL Guadalajara Oblatos OBL" value='107'>Oblatos</option><option data-tokens="Jalisco JAL GDL Guadalajara Santa Fe SFE" value='108'>Santa Fe</option><option data-tokens="Jalisco JAL GDL Guadalajara Tlaquepaque TLA" value='109'>Tlaquepaque</option><option data-tokens="Jalisco JAL GDL Guadalajara Vallarta VAL" value='110'>Vallarta</option></optgroup><optgroup label='Red: Guanajuato' ><option data-tokens="Guanajuato GTO GTO Guanajuato Universidad Gto Sede Belen UG-B" value='359'>Universidad Gto Sede Belen</option></optgroup><optgroup label='Red: Guasave' ></optgroup><optgroup label='Red: Guerrero' ><option data-tokens="Guerrero GUE GUE Guerrero Protección Civil PC" value='293'>Protección Civil</option></optgroup><optgroup label='Red: Huichapan' ><option data-tokens="Hidalgo HGO HUI Huichapan Hospital HUI" value='85'>Hospital</option></optgroup><optgroup label='Red: Huimanguillo' ></optgroup><optgroup label='Red: Irapuato' ><option data-tokens="Guanajuato GTO IRA Irapuato Bomberos BOM" value='72'>Bomberos</option><option data-tokens="Guanajuato GTO IRA Irapuato Sec. Oficial SEC" value='71'>Sec. Oficial</option><option data-tokens="Guanajuato GTO IRA Irapuato Teódula TEO" value='73'>Teódula</option></optgroup><optgroup label='Red: Juventino Rosas' ></optgroup><optgroup label='Red: León' ><option data-tokens="Guanajuato GTO LEO León CICEG - Bomberos CC" value='74'>CICEG - Bomberos</option><option data-tokens="Guanajuato GTO LEO León Facultad de Medicina FM" value='75'>Facultad de Medicina</option><option data-tokens="Guanajuato GTO LEO León T21 T21" value='76'>T21</option></optgroup><optgroup label='Red: Lerdo' ><option data-tokens="Durango DGO LER Lerdo SAGARPA SAG" value='67'>SAGARPA</option><option data-tokens="Durango DGO LER Lerdo Tecnológico Lerdo LE" value='342'>Tecnológico Lerdo</option></optgroup><optgroup label='Red: Lolotla' ></optgroup><optgroup label='Red: Los Mochis (Ahome)' ><option data-tokens="Sinaloa SIN AHO Los Mochis (Ahome) DIF Municipal ELM1" value='181'>DIF Municipal</option></optgroup><optgroup label='Red: Mazatlán' ><option data-tokens="Sinaloa SIN MZT Mazatlán Junta Municipal de Agua Potable EMZT1" value='179'>Junta Municipal de Agua Potable</option></optgroup><optgroup label='Red: Mérida' ><option data-tokens="Yucatán YUC MID Mérida SDS01 CEN" value='236'>SDS01</option></optgroup><optgroup label='Red: Mexicali' ><option data-tokens="Baja California - Estatal BC1 MXC Mexicali CESPM SPABC19" value='41'>CESPM</option><option data-tokens="Baja California - Estatal BC1 MXC Mexicali COBACH SPABC14" value='39'>COBACH</option><option data-tokens="Baja California - Estatal BC1 MXC Mexicali UPBC SPABC22" value='42'>UPBC</option></optgroup><optgroup label='Red: Minatitlán' ><option data-tokens="Veracruz VER MIN Minatitlán Tecnológico TEC" value='234'>Tecnológico</option></optgroup><optgroup label='Red: Monclova' ><option data-tokens="Coahuila COAH1 MON Monclova Jurisdicción Sanitaria JUR" value='305'>Jurisdicción Sanitaria</option></optgroup><optgroup label='Red: Monterrey' ><option data-tokens="Nuevo León NLE MTY Monterrey Apodaca NE2" value='146'>Apodaca</option><option data-tokens="Nuevo León NLE MTY Monterrey Cadereyta SE3" value='424'>Cadereyta</option><option data-tokens="Nuevo León NLE MTY Monterrey Escobedo N" value='144'>Escobedo</option><option data-tokens="Nuevo León NLE MTY Monterrey García NO2" value='145'>García</option><option data-tokens="Nuevo León NLE MTY Monterrey Juárez SE2" value='147'>Juárez</option><option data-tokens="Nuevo León NLE MTY Monterrey La Pastora SE" value='143'>La Pastora</option><option data-tokens="Nuevo León NLE MTY Monterrey Obispado CE" value='141'>Obispado</option><option data-tokens="Nuevo León NLE MTY Monterrey Pueblo Serena SUR" value='426'>Pueblo Serena</option><option data-tokens="Nuevo León NLE MTY Monterrey San Bernabé NO" value='140'>San Bernabé</option><option data-tokens="Nuevo León NLE MTY Monterrey San Nicolás NE" value='142'>San Nicolás</option><option data-tokens="Nuevo León NLE MTY Monterrey San Pedro SO2" value='148'>San Pedro</option><option data-tokens="Nuevo León NLE MTY Monterrey Santa Catarina SO" value='139'>Santa Catarina</option><option data-tokens="Nuevo León NLE MTY Monterrey Universidad N2" value='425'>Universidad</option></optgroup><optgroup label='Red: Morelia' ><option data-tokens="Michoacán MICH MRA Morelia Laboratorio de Salud LAB" value='131'>Laboratorio de Salud</option><option data-tokens="Michoacán MICH MRA Morelia Palacio Municipal ECH" value='388'>Palacio Municipal</option><option data-tokens="Michoacán MICH MRA Morelia Universidad Michoacana de San Nicolás Hidalgo ECU" value='129'>Universidad Michoacana de San Nicolás Hidalgo</option></optgroup><optgroup label='Red: Moroleon' ></optgroup><optgroup label='Red: Municipio de Juárez' ><option data-tokens="Chihuahua - Ciudad Juárez CHIH3 CJU Municipio de Juárez Advance ADV" value='112'>Advance</option><option data-tokens="Chihuahua - Ciudad Juárez CHIH3 CJU Municipio de Juárez Canales Lira CLB" value='111'>Canales Lira</option><option data-tokens="Chihuahua - Ciudad Juárez CHIH3 CJU Municipio de Juárez Delphi DEL" value='407'>Delphi</option></optgroup><optgroup label='Red: Municipio de Mexicali' ><option data-tokens="Baja California - Municipal BC2 MXCM Municipio de Mexicali Palacio Municipal PMN" value='437'>Palacio Municipal</option></optgroup><optgroup label='Red: Nogales' ><option data-tokens="Sonora SON NOG Nogales Instituto Tecnológico de Nogales TEC" value='187'>Instituto Tecnológico de Nogales</option></optgroup><optgroup label='Red: Oaxaca' ><option data-tokens="Oaxaca OAX OAX Oaxaca Casa Hogar CHO" value='297'>Casa Hogar</option><option data-tokens="Oaxaca OAX OAX Oaxaca CEDART CED" value='160'>CEDART</option></optgroup><optgroup label='Red: Pachuca' ><option data-tokens="Hidalgo HGO PAC Pachuca Jardín del Maestro JDN" value='92'>Jardín del Maestro</option><option data-tokens="Hidalgo HGO PAC Pachuca Museo del Rehilete REH" value='93'>Museo del Rehilete</option></optgroup><optgroup label='Red: Paraíso' ></optgroup><optgroup label='Red: Piedras Negras' ><option data-tokens="Coahuila COAH1 PDS Piedras Negras Centro de Rehabilitación DIF DIF" value='306'>Centro de Rehabilitación DIF</option></optgroup><optgroup label='Red: Poza Rica' ><option data-tokens="Veracruz VER POZ Poza Rica Universidad Veracruzana PR-03" value='291'>Universidad Veracruzana</option></optgroup><optgroup label='Red: Puebla' ><option data-tokens="Puebla PUE PUE Puebla Agua Santa STA" value='161'>Agua Santa</option><option data-tokens="Puebla PUE PUE Puebla Benemérito Instituto Normal del Estado BINE" value='163'>Benemérito Instituto Normal del Estado</option><option data-tokens="Puebla PUE PUE Puebla Las Ninfas NIN" value='162'>Las Ninfas</option><option data-tokens="Puebla PUE PUE Puebla Universidad Tecnológica de Puebla UTP" value='406'>Universidad Tecnológica de Puebla</option><option data-tokens="Puebla PUE PUE Puebla Velódromo VEL" value='165'>Velódromo</option></optgroup><optgroup label='Red: Purísima del Rincón' ><option data-tokens="Guanajuato GTO PUR Purísima del Rincón Purísima del Rincón PUR" value='423'>Purísima del Rincón</option></optgroup><optgroup label='Red: Rosarito' ><option data-tokens="Baja California - Estatal BC1 ROS Rosarito Rosarito SPABC04" value='43'>Rosarito</option></optgroup><optgroup label='Red: Salamanca' ><option data-tokens="Guanajuato GTO SAL Salamanca Cruz roja CR" value='77'>Cruz roja</option><option data-tokens="Guanajuato GTO SAL Salamanca DIF DIF" value='78'>DIF</option><option data-tokens="Guanajuato GTO SAL Salamanca Nativitas NAT" value='79'>Nativitas</option></optgroup><optgroup label='Red: Saltillo' ><option data-tokens="Coahuila COAH1 SLW Saltillo Finanzas FIN" value='304'>Finanzas</option></optgroup><optgroup label='Red: Salvador Alvarado' ></optgroup><optgroup label='Red: San Francisco del Rincón' ></optgroup><optgroup label='Red: San José Iturbide' ></optgroup><optgroup label='Red: San Juan del Rio' ><option data-tokens="Querétaro QRO SJR San Juan del Rio Universidad Autónoma de Querétaro SJU" value='410'>Universidad Autónoma de Querétaro</option></optgroup><optgroup label='Red: San Luis de la Paz' ><option data-tokens="Guanajuato GTO SPZ San Luis de la Paz Presidencia Municipal SLP" value='358'>Presidencia Municipal</option></optgroup><optgroup label='Red: San Luis Potosí Estatal' ><option data-tokens="San Luis Potosí SLP SLP San Luis Potosí Estatal Biblioteca BIB" value='174'>Biblioteca</option><option data-tokens="San Luis Potosí SLP SLP San Luis Potosí Estatal DIF DIF" value='172'>DIF</option><option data-tokens="San Luis Potosí SLP SLP San Luis Potosí Estatal Escuela Primaria 1° de mayo PRIM" value='427'>Escuela Primaria 1° de mayo</option><option data-tokens="San Luis Potosí SLP SLP San Luis Potosí Estatal Industriales Potosinos Asociados IPAC" value='171'>Industriales Potosinos Asociados</option></optgroup><optgroup label='Red: San Luis Río Colorado' ></optgroup><optgroup label='Red: San Miguel de Allende' ><option data-tokens="Guanajuato GTO SMA San Miguel de Allende Presidencia Municipal PRE-SMA" value='352'>Presidencia Municipal</option></optgroup><optgroup label='Red: Santiago de Querétaro' ><option data-tokens="Querétaro QRO SQ Santiago de Querétaro Auditorio Josefa Ortíz AJO" value='409'>Auditorio Josefa Ortíz</option><option data-tokens="Querétaro QRO SQ Santiago de Querétaro Bomberos BOM" value='170'>Bomberos</option><option data-tokens="Querétaro QRO SQ Santiago de Querétaro Delegación Carrillo CAP" value='408'>Delegación Carrillo</option><option data-tokens="Querétaro QRO SQ Santiago de Querétaro Epigmenio González EPG" value='168'>Epigmenio González</option><option data-tokens="Querétaro QRO SQ Santiago de Querétaro Félix Osores FEO" value='169'>Félix Osores</option></optgroup><optgroup label='Red: Silao' ><option data-tokens="Guanajuato GTO SIL Silao Hospital General HG" value='80'>Hospital General</option></optgroup><optgroup label='Red: Tampico' ></optgroup><optgroup label='Red: Tecate' ><option data-tokens="Baja California - Estatal BC1 TKT Tecate Tecate SPABC23" value='44'>Tecate</option></optgroup><optgroup label='Red: Tepeapulco' ><option data-tokens="Hidalgo HGO TEP Tepeapulco Estación de Bomberos de Cd. Sahagún TEP" value='84'>Estación de Bomberos de Cd. Sahagún</option></optgroup><optgroup label='Red: Tepeji' ><option data-tokens="Hidalgo HGO TPJ Tepeji Primaria Melchor Ocampo TPJ" value='87'>Primaria Melchor Ocampo</option></optgroup><optgroup label='Red: Tepetitlán' ></optgroup><optgroup label='Red: Tepic' ><option data-tokens="Nayarit NAY TPC Tepic Primaria Julián Gascón Mercado PRIM" value='137'>Primaria Julián Gascón Mercado</option><option data-tokens="Nayarit NAY TPC Tepic Tecnológico de Tepic TEC" value='136'>Tecnológico de Tepic</option></optgroup><optgroup label='Red: Tijuana' ><option data-tokens="Baja California - Estatal BC1 TIJ Tijuana La Mesa SPABC03" value='47'>La Mesa</option><option data-tokens="Baja California - Estatal BC1 TIJ Tijuana Laboratorio SPABC21" value='46'>Laboratorio</option><option data-tokens="Baja California - Estatal BC1 TIJ Tijuana Tecnológico SPABC01" value='45'>Tecnológico</option></optgroup><optgroup label='Red: Tizayuca' ><option data-tokens="Hidalgo HGO TIZ Tizayuca Biblioteca TIZ" value='96'>Biblioteca</option></optgroup><optgroup label='Red: Tlaxcala' ><option data-tokens="Tlaxcala TLAX TLAX Tlaxcala Palacio de Gobierno PGO" value='220'>Palacio de Gobierno</option></optgroup><optgroup label='Red: Tlaxcoapan' ></optgroup><optgroup label='Red: Toluca' ><option data-tokens="México EDOMEX TLC Toluca Aeropuerto AP" value='122'>Aeropuerto</option><option data-tokens="México EDOMEX TLC Toluca Ceboruco CB" value='123'>Ceboruco</option><option data-tokens="México EDOMEX TLC Toluca Metepec MT" value='125'>Metepec</option><option data-tokens="México EDOMEX TLC Toluca Oxtotitlán OX" value='126'>Oxtotitlán</option><option data-tokens="México EDOMEX TLC Toluca San Cristobal SC" value='127'>San Cristobal</option><option data-tokens="México EDOMEX TLC Toluca San Mateo Atenco SM" value='128'>San Mateo Atenco</option><option data-tokens="México EDOMEX TLC Toluca Toluca Centro CE" value='124'>Toluca Centro</option></optgroup><optgroup label='Red: Torreón' ><option data-tokens="Coahuila COAH1 TORR Torreón CONALEP CNP" value='56'>CONALEP</option></optgroup><optgroup label='Red: Torreón Municipal' ><option data-tokens="Coahuila - Torreón COAH2 TOR Torreón Municipal Hospital Infantil HOS" value='340'>Hospital Infantil</option></optgroup><optgroup label='Red: Tula' ><option data-tokens="Hidalgo HGO TUL Tula Centro de Salud CSA" value='90'>Centro de Salud</option></optgroup><optgroup label='Red: Tulancingo' ><option data-tokens="Hidalgo HGO TLN Tulancingo Tulancingo TLN" value='292'>Tulancingo</option></optgroup><optgroup label='Red: Tuxtla Gutiérrez' ><option data-tokens="Chiapas CHIS TUX Tuxtla Gutiérrez Palacio Municipal PMN" value='50'>Palacio Municipal</option></optgroup><optgroup label='Red: Valle de México' ><option data-tokens="Ciudad de México CDMX CMX Valle de México Ajusco Medio AJM" value='242'>Ajusco Medio</option><option data-tokens="Ciudad de México CDMX CMX Valle de México Atizapán ATI" value='243'>Atizapán</option><option data-tokens="Ciudad de México CDMX CMX Valle de México Benito Juárez BJU" value='300'>Benito Juárez</option><option data-tokens="Ciudad de México CDMX CMX Valle de México Camarones CAM" value='244'>Camarones</option><option data-tokens="Ciudad de México CDMX CMX Valle de México Centro de Ciencias de la Atmósfera CCA" value='245'>Centro de Ciencias de la Atmósfera</option><option data-tokens="Ciudad de México CDMX CMX Valle de México Chalco CHO" value='246'>Chalco</option><option data-tokens="Ciudad de México CDMX CMX Valle de México Cuajimalpa CUA" value='248'>Cuajimalpa</option><option data-tokens="Ciudad de México CDMX CMX Valle de México Cuautitlán CUT" value='249'>Cuautitlán</option><option data-tokens="Ciudad de México CDMX CMX Valle de México FES Acatlán FAC" value='250'>FES Acatlán</option><option data-tokens="Ciudad de México CDMX CMX Valle de México FES Aragón FAR" value='431'>FES Aragón</option><option data-tokens="Ciudad de México CDMX CMX Valle de México Gustavo A. Madero GAM" value='302'>Gustavo A. Madero</option><option data-tokens="Ciudad de México CDMX CMX Valle de México Hospital General de México HGM" value='251'>Hospital General de México</option><option data-tokens="Ciudad de México CDMX CMX Valle de México Iztacalco IZT" value='252'>Iztacalco</option><option data-tokens="Ciudad de México CDMX CMX Valle de México La Presa LPR" value='253'>La Presa</option><option data-tokens="Ciudad de México CDMX CMX Valle de México Los Laureles LLA" value='254'>Los Laureles</option><option data-tokens="Ciudad de México CDMX CMX Valle de México Merced MER" value='256'>Merced</option><option data-tokens="Ciudad de México CDMX CMX Valle de México Miguel Hidalgo MGH" value='263'>Miguel Hidalgo</option><option data-tokens="Ciudad de México CDMX CMX Valle de México Nezahualcóyotl NEZ" value='258'>Nezahualcóyotl</option><option data-tokens="Ciudad de México CDMX CMX Valle de México Pedregal PED" value='259'>Pedregal</option><option data-tokens="Ciudad de México CDMX CMX Valle de México San Agustín SAG" value='260'>San Agustín</option><option data-tokens="Ciudad de México CDMX CMX Valle de México Santa Fe SFE" value='262'>Santa Fe</option><option data-tokens="Ciudad de México CDMX CMX Valle de México Santiago Acahualtepec SAC" value='432'>Santiago Acahualtepec</option><option data-tokens="Ciudad de México CDMX CMX Valle de México Tlahuac TAH" value='265'>Tlahuac</option><option data-tokens="Ciudad de México CDMX CMX Valle de México Tlalnepantla TLA" value='266'>Tlalnepantla</option><option data-tokens="Ciudad de México CDMX CMX Valle de México Tultitlán TLI" value='267'>Tultitlán</option><option data-tokens="Ciudad de México CDMX CMX Valle de México UAM Iztapalapa UIZ" value='268'>UAM Iztapalapa</option><option data-tokens="Ciudad de México CDMX CMX Valle de México UAM Xochimilco UAX" value='269'>UAM Xochimilco</option><option data-tokens="Ciudad de México CDMX CMX Valle de México Villa de las Flores VIF" value='270'>Villa de las Flores</option><option data-tokens="Ciudad de México CDMX CMX Valle de México Xalostoc XAL" value='271'>Xalostoc</option></optgroup><optgroup label='Red: Villagrán' ></optgroup><optgroup label='Red: Xalapa' ><option data-tokens="Veracruz VER XAL Xalapa STPS STP" value='235'>STPS</option></optgroup><optgroup label='Red: Xochicoatlán' ></optgroup><optgroup label='Red: Zacatecas' ><option data-tokens="Zacatecas ZAC ZAC Zacatecas Explanada del Congreso CDA" value='294'>Explanada del Congreso</option></optgroup><optgroup label='Red: Zacatepec' ><option data-tokens="Morelos MOR ZAC Zacatepec Tecnológico de Zacatepec TEC" value='135'>Tecnológico de Zacatepec</option></optgroup><optgroup label='Red: Zapotlán' ></optgroup>"""
estacion=pd.DataFrame(columns=['estacion','id'])
y=0
for n in re.findall(r'<option(.*?)</option', string):
    estacion.loc[y] = pd.Series({'estacion':re.findall(r'data-tokens=(.*?)value', n)[0], 'id':re.findall(r' value=\'(.*)\'' , n)[0]})
    y=y+1
estacion.to_csv('estaciones.csv')
estacion
# Out:
#                                               estacion   id
# 0    "Guanajuato GTO ABA Abasolo Presidencia Munici...  356
# 1    "Aguascalientes AGS AGS Aguascalientes CBTIS  ...   31
# 2    "Aguascalientes AGS AGS Aguascalientes Centro ...   33
# 3    "Aguascalientes AGS AGS Aguascalientes Institu...  303
# 4    "Aguascalientes AGS AGS Aguascalientes Secreta...   32
# ..                                                 ...  ...
# 156  "Ciudad de México CDMX CMX Valle de México Vil...  270
# 157  "Ciudad de México CDMX CMX Valle de México Xal...  271
# 158                "Veracruz VER XAL Xalapa STPS STP"   235
# 159  "Zacatecas ZAC ZAC Zacatecas Explanada del Con...  294
# 160  "Morelos MOR ZAC Zacatepec Tecnológico de Zaca...  135
#
# [161 rows x 2 columns]

# %% [markdown]
# ## poner fecha de inicio y estaciones

# %%
Estaciones=[144] #[144,146] separadas por comas
sensores = ['PM10','PM2.5','CO'] #separados por comas ['PM10','PM2.5','CO']
t0="2020-01-01" #tiempo de inicio  2017-01-01

# %%
import datetime
import requests
from bs4 import BeautifulSoup
import json
import pandas as pd

#funcion para pedir datos
def wrapersinaica(estacion,sensor,fecha):
    rango= 4
    conta = sensor
    url='https://sinaica.inecc.gob.mx/pags/datGrafs.php'
    params ={'estacionId':str(estacion),'param':str(conta),'fechaIni':str(fecha),'rango':str(rango),'tipoDatos':''}

    response=requests.post(url, data=params)
    soup1 = BeautifulSoup(response.text, 'lxml')
    reportes = soup1.find_all('script')[2]
    r = str(reportes)
    r1 = r.split(' dat = ') #extraccion de datos
    r2 = r1[1].rsplit(';\n\n\t\tif(dat.length == 0)') #extraccion de datos
    r3 = r2[0].rsplit("['(.*?)']") #extraccion de datos
    JsonText=r3[0] #extraccion de datos
    return JsonText
#funcion para new
def datosorganizar(JsonText,sensor,estacion):
    Estacion=pd.read_json(JsonText) #crear data frame con JsonText
    Estacion['sensor'] = sensor 
    Estacion['estacion'] = estacion
    Estacion['fechahora']= 0
    #print(Estacion)
    for index, row in Estacion.iterrows():
        Estacion['fechahora'][index]=datetime.datetime.strptime(row['fecha'],"%Y-%m-%d") + pd.tseries.offsets.Timedelta(hours=row['hora'])
        #print(row['fechahora'], row['hora'])
    #Cambiar nombre de valor a sensor
    Estacion.rename(columns={'valor':sensor},inplace=True)
    return Estacion

# %%
## va requerir LISTA de SENSORES, fecha de inicio, LISTA DE ESTACIONES
Dates =[]
u = datetime.datetime.strptime(t0,"%Y-%m-%d")# YYYY-MM-DD
hoy = datetime.datetime.today()
while u <= hoy :
    Dates.append(u.strftime('%Y-%m-%d'))
    u = u +datetime.timedelta(days = 28) #sumarle 4 semanas
#La lista quedo guardada en Dates

for es in Estaciones:
    print('id estacion'+ str(es))
    sensor_dict = {} #para guardar como variables dinamicas los sensores de cada estacion.

    for s in sensores:
        sensor_dict[s] = pd.DataFrame(columns=['id', 'fecha', 'hora', s, 'bandO', 'val', 'sensor', 'estacion',
           'fechahora'])
        sensor_dict[s]
        for d in Dates:
            sensor_dict[s]=sensor_dict[s].append(datosorganizar(wrapersinaica(es,s,d),s,es))#hay que agarrarlo de la lista
            #print(d)

    Junta=pd.DataFrame(columns=sensores) #crear columnas de lista en diccionario
    for n in sensor_dict:
        print(n)
        for index, row in sensor_dict[n].iterrows():
            Junta.loc[row['fechahora'], n] = row[n] #.loc no deberia usarse asi, muy ineficiente.
    Junta.to_csv(str(es)+'.csv')
